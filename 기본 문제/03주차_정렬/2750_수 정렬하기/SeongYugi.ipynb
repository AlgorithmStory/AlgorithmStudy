# %% [markdown]
# [2750] N개의 수가 주어졌을 때, 이를 오름차순으로 정렬하는 프로그램을 작성하시오.

# %%
N = int(input())
arr =[]

for i in range(N) :
    num = int(input())
    arr.append(num)

#print(arr)
arr.sort()

for j in arr :
    print(j)
# Out:
# 5
# 5
# 4
# 3
# 2
# 1
# 1
# 2
# 3
# 4
# 5
